# %%
# Import required packages
import xml.etree.ElementTree as ET
import re

# %%
def parse_xml(xml_file_name):
    # Parse XML tree and returns it's root
    tree = ET.parse('wf_src_idw_cntry_multi_def_cd.xml')
    # Get root element
    root = tree.getroot()
    return root

# %%
def parse_transformfield(root, dict_obj):
    # Loop through the iterrable element "TRANSFORMFIELD" as these only contains the transformations embedded in them
    for trans in root.iter('TRANSFORMFIELD'):
        attribute = trans.attrib
        # Consider only those transformfields which has "EXPRESSION" as one of it's attribute
        if 'EXPRESSION' in attribute:
    #         print(attribute)
            # Check if there exists any opening parenthesis in the EXPRESSION attribute
            # If it doesn't exists , this means the transformation function doesn't take any input else it does
            if('(' not in attribute['EXPRESSION']):
                # If Port type is Input/Output then same field is acting as INPUT as well as OUTPUT
                if('INPUT/OUTPUT' in attribute['PORTTYPE']):
                    inp_col = str(attribute['NAME']).strip()
                    trans = str(attribute['EXPRESSION']).strip()
                    out_col = str(attribute['NAME']).strip()
                    print('source(' + inp_col + ') -> transformation(' + trans + ') -> target(' + out_col + ')')
                else: # If Port type is Output then input will be None as the transformation function does not takes in any input
                    inp_col = 'None'
                    trans = str(attribute['EXPRESSION']).strip()
                    out_col = str(attribute['NAME']).strip()
                    print('source(' + inp_col + ') -> transformation(' + trans + ') -> target(' + out_col + ')')
            else:
                # This section means transformation function does take some input
                # Reading text in between '(' and ')'
                match = re.findall(r'\((.*)\)', attribute['EXPRESSION'])
                inp_col = match[0].split(',')[0]
                trans = str(attribute['EXPRESSION']).strip()
                out_col = str(attribute['NAME']).strip()
                print('source(' + inp_col + ') -> transformation(' + trans + ') -> target(' + out_col + ')')
    return dict_obj

# %%
def parse_connectorfield(root, dict_obj):
    for trans in root.iter('CONNECTOR'):
        attribute = trans.attrib
        inp_col = str(attribute['FROMFIELD']).strip()
        trans = str(attribute['FROMINSTANCE']).strip()
        out_col = str(attribute['TOFIELD']).strip()
        print('source(' + inp_col + ') -> transformation(' + trans + ') -> target(' + out_col + ')')
    return dict_obj

# %%
xml_file_name = 'wf_src_idw_cntry_multi_def_cd.xml'
root = parse_xml(xml_file_name)

parse_transformfield(root, dict_obj)
parse_connectorfield(root, dic_1)
# Out:
# source(IN_OUTPUT_RUNDATE ) -> transformation(TO_DATE
# (IN_OUTPUT_RUNDATE ,'YYYY-MM-DD')) -> target(OUT_DW_AS_OF_DT)
# source(IN_AUDIT_UPDT_TS) -> transformation(TO_DATE(IN_AUDIT_UPDT_TS,'YYYY-MM-DD HH24.MI.SS')) -> target(OUT_AUDIT_UPDT_TS)
# source(None) -> transformation(SESSSTARTTIME) -> target(OUT_DW_LOAD_TS)
# source(SWB_CNTRY_ID) -> transformation(SWB_CNTRY_ID) -> target(SWB_CNTRY_ID)
# source(CNTRY_SCHEME_CD) -> transformation(CNTRY_SCHEME_CD) -> target(CNTRY_SCHEME_CD)
# source(DW_AS_OF_DT) -> transformation(DW_AS_OF_DT) -> target(DW_AS_OF_DT)
# source('9999-12-31') -> transformation(TO_DATE('9999-12-31','YYYY-MM-DD')) -> target(OUT_DW_EXPR_DT)
# source(None) -> transformation(1) -> target(OUT_CURR_IN)
# source(None) -> transformation(0) -> target(OUT_RCV_IN)
# source(CNTRY_CD) -> transformation(CNTRY_CD) -> target(CNTRY_CD)
# source(CNTRY_NM) -> transformation(CNTRY_NM) -> target(CNTRY_NM)
# source(CNTRY_SCHM_VALD_IN) -> transformation(CNTRY_SCHM_VALD_IN) -> target(CNTRY_SCHM_VALD_IN)
# source(AUDIT_UPDT_USER_ID) -> transformation(AUDIT_UPDT_USER_ID) -> target(AUDIT_UPDT_USER_ID)
# source(AUDIT_UPDT_TS) -> transformation(AUDIT_UPDT_TS) -> target(AUDIT_UPDT_TS)
# source(None) -> transformation(SESSSTARTTIME) -> target(OUT_DW_LOAD_TS)
# source(SWB_CNTRY_ID) -> transformation(SWB_CNTRY_ID) -> target(SWB_CNTRY_ID)
# source(CNTRY_SCHEME_CD) -> transformation(CNTRY_SCHEME_CD) -> target(CNTRY_SCHEME_CD)
# source(DW_AS_OF_DT) -> transformation(DW_AS_OF_DT) -> target(DW_AS_OF_DT)
# source('9999-12-31' ) -> transformation(TO_DATE('9999-12-31' , 'YYYY-MM-DD')) -> target(OUT_DW_EXPR_DT)
# source(None) -> transformation(1) -> target(OUT_CURR_IN)
# source(None) -> transformation(1) -> target(OUT_RCV_IN)
# source(CNTRY_CD) -> transformation(CNTRY_CD) -> target(CNTRY_CD)
# source(CNTRY_NM) -> transformation(CNTRY_NM) -> target(CNTRY_NM)
# source(CNTRY_SCHM_VALD_IN) -> transformation(CNTRY_SCHM_VALD_IN) -> target(CNTRY_SCHM_VALD_IN)
# source(AUDIT_UPDT_USER_ID) -> transformation(AUDIT_UPDT_USER_ID) -> target(AUDIT_UPDT_USER_ID)
# source(AUDIT_UPDT_TS) -> transformation(AUDIT_UPDT_TS) -> target(AUDIT_UPDT_TS)
# source(None) -> transformation(SESSSTARTTIME) -> target(OUT_DW_LAOD_TS)
# source(SWB_CNTRY_ID) -> transformation(SWB_CNTRY_ID) -> target(SWB_CNTRY_ID)
# source(CNTRY_TYPE_CD) -> transformation(CNTRY_TYPE_CD) -> target(CNTRY_TYPE_CD)
# source(DW_EFF_DT) -> transformation(DW_EFF_DT) -> target(DW_EFF_DT)
# source(IN_DW_AS_OF_DT) -> transformation(ADD_TO_DATE(IN_DW_AS_OF_DT,'DD', -1)) -> target(OUT_DW_EXPR_DT)
# source(None) -> transformation(0) -> target(OUT_CURR_IN)
# source(None) -> transformation(SESSSTARTTIME) -> target(OUT_DW_LOAD_TS)
# source(SWB_CNTRY_ID) -> transformation(SWB_CNTRY_ID) -> target(SWB_CNTRY_ID)
# source(CNTRY_TYPE_CD) -> transformation(CNTRY_TYPE_CD) -> target(CNTRY_TYPE_CD)
# source(DW_EFF_DT) -> transformation(DW_EFF_DT) -> target(DW_EFF_DT)
# source(IN_DW_AS_OF_DT) -> transformation(ADD_TO_DATE(IN_DW_AS_OF_DT,'DD', -1)) -> target(OUT_DW_EXPR_DT)
# source(None) -> transformation(0) -> target(OUT_CURR_IN)
# source(None) -> transformation(SESSSTARTTIME) -> target(OUT_DW_LOAD_TS)
# source(OUT_DW_LOAD_TS) -> transformation(exp_cntry_multi_def_cd) -> target(DW_LOAD_TS)
# source(OUT_DW_AS_OF_DT) -> transformation(exp_cntry_multi_def_cd) -> target(DW_AS_OF_DT)
# source(CHANGE_IND) -> transformation(SQ_cntry_multi_def_cd_daily) -> target(DW_ACTN_IND)
# source(SWB_CNTRY_ID) -> transformation(SQ_cntry_multi_def_cd_daily) -> target(SWB_CNTRY_ID)
# source(CNTRY_SCHEME_CD) -> transformation(SQ_cntry_multi_def_cd_daily) -> target(CNTRY_SCHEME_CD)
# source(CNTRY_SCHM_VALD_IN) -> transformation(SQ_cntry_multi_def_cd_daily) -> target(CNTRY_SCHM_VALD_IN)
# source(CNTRY_CD) -> transformation(SQ_cntry_multi_def_cd_daily) -> target(CNTRY_CD)
# source(AUDIT_UPDT_USER_ID) -> transformation(SQ_cntry_multi_def_cd_daily) -> target(AUDIT_UPDT_USER_ID)
# source(OUT_AUDIT_UPDT_TS) -> transformation(exp_cntry_multi_def_cd) -> target(AUDIT_UPDT_TS)
# source(CNTRY_NM) -> transformation(SQ_cntry_multi_def_cd_daily) -> target(CNTRY_NM)
# source(OUTPUT_RUNDATE) -> transformation(SQ_cntry_multi_def_cd_daily) -> target(IN_OUTPUT_RUNDATE)
# source(AUDIT_UPDT_TS) -> transformation(SQ_cntry_multi_def_cd_daily) -> target(IN_AUDIT_UPDT_TS)
# source(CHANGE_IND) -> transformation(cntry_multi_def_cd_daily) -> target(CHANGE_IND)
# source(SWB_CNTRY_ID) -> transformation(cntry_multi_def_cd_daily) -> target(SWB_CNTRY_ID)
# source(CNTRY_SCHEME_CD) -> transformation(cntry_multi_def_cd_daily) -> target(CNTRY_SCHEME_CD)
# source(CNTRY_SCHM_VALD_IN) -> transformation(cntry_multi_def_cd_daily) -> target(CNTRY_SCHM_VALD_IN)
# source(CNTRY_CD) -> transformation(cntry_multi_def_cd_daily) -> target(CNTRY_CD)
# source(CNTRY_NM) -> transformation(cntry_multi_def_cd_daily) -> target(CNTRY_NM)
# source(AUDIT_UPDT_USER_ID) -> transformation(cntry_multi_def_cd_daily) -> target(AUDIT_UPDT_USER_ID)
# source(AUDIT_UPDT_TS) -> transformation(cntry_multi_def_cd_daily) -> target(AUDIT_UPDT_TS)
# source(OUTPUT_RUNDATE) -> transformation(cntry_multi_def_cd_daily) -> target(OUTPUT_RUNDATE)
# source(OUT_DW_EXPR_DT) -> transformation(upd_cntry_multi_def_cd_UPD_CHG) -> target(DW_EXPR_DT)
# source(SWB_CNTRY_ID) -> transformation(upd_cntry_multi_def_cd_UPD_CHG) -> target(SWB_CNTRY_ID)
# source(CNTRY_TYPE_CD) -> transformation(upd_cntry_multi_def_cd_UPD_CHG) -> target(CNTRY_TYPE_CD)
# source(DW_EFF_DT) -> transformation(upd_cntry_multi_def_cd_UPD_CHG) -> target(DW_EFF_DT)
# source(OUT_CURR_IN) -> transformation(upd_cntry_multi_def_cd_UPD_CHG) -> target(CURR_IN)
# source(OUT_DW_LOAD_TS) -> transformation(upd_cntry_multi_def_cd_UPD_CHG) -> target(DW_LOAD_TS)
# source(OUT_DW_LOAD_TS) -> transformation(upd_del_cntry_multi_def_cd) -> target(DW_LOAD_TS)
# source(SWB_CNTRY_ID) -> transformation(upd_del_cntry_multi_def_cd) -> target(SWB_CNTRY_ID)
# source(CNTRY_TYPE_CD) -> transformation(upd_del_cntry_multi_def_cd) -> target(CNTRY_TYPE_CD)
# source(DW_EFF_DT) -> transformation(upd_del_cntry_multi_def_cd) -> target(DW_EFF_DT)
# source(OUT_DW_EXPR_DT) -> transformation(upd_del_cntry_multi_def_cd) -> target(DW_EXPR_DT)
# source(OUT_CURR_IN) -> transformation(upd_del_cntry_multi_def_cd) -> target(CURR_IN)
# source(CNTRY_SCHEME_CD) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(CNTRY_TYPE_CD)
# source(OUT_DW_EXPR_DT) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(DW_EXPR_DT)
# source(OUT_CURR_IN) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(CURR_IN)
# source(OUT_RCV_IN) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(RCV_IN)
# source(CNTRY_NM) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(CNTRY_NM)
# source(CNTRY_CD) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(CNTRY_CD)
# source(CNTRY_SCHM_VALD_IN) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(CNTRY_TYPE_VALID_IN)
# source(AUDIT_UPDT_USER_ID) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(AUDIT_UPDT_USER_ID)
# source(AUDIT_UPDT_TS) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(AUDIT_UPDT_TS)
# source(OUT_DW_LOAD_TS) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(DW_LOAD_TS)
# source(DW_AS_OF_DT) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(DW_EFF_DT)
# source(SWB_CNTRY_ID) -> transformation(exp_cntry_multi_def_cd_INS_DEL) -> target(SWB_CNTRY_ID)
# source(CNTRY_CD) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(CNTRY_CD)
# source(SWB_CNTRY_ID) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(SWB_CNTRY_ID)
# source(CNTRY_SCHEME_CD) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(CNTRY_TYPE_CD)
# source(DW_AS_OF_DT) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(DW_EFF_DT)
# source(CNTRY_NM) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(CNTRY_NM)
# source(CNTRY_SCHM_VALD_IN) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(CNTRY_TYPE_VALID_IN)
# source(AUDIT_UPDT_USER_ID) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(AUDIT_UPDT_USER_ID)
# source(AUDIT_UPDT_TS) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(AUDIT_UPDT_TS)
# source(OUT_DW_LAOD_TS) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(DW_LOAD_TS)
# source(OUT_DW_EXPR_DT) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(DW_EXPR_DT)
# source(OUT_CURR_IN) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(CURR_IN)
# source(OUT_RCV_IN) -> transformation(exp_cntry_multi_def_cd_ins_new) -> target(RCV_IN)
# source(SWB_CNTRY_ID) -> transformation(exp_cntry_multi_def_cd_upd_chg) -> target(SWB_CNTRY_ID)
# source(CNTRY_TYPE_CD) -> transformation(exp_cntry_multi_def_cd_upd_chg) -> target(CNTRY_TYPE_CD)
# source(DW_EFF_DT) -> transformation(exp_cntry_multi_def_cd_upd_chg) -> target(DW_EFF_DT)
# source(OUT_DW_EXPR_DT) -> transformation(exp_cntry_multi_def_cd_upd_chg) -> target(OUT_DW_EXPR_DT)
# source(OUT_CURR_IN) -> transformation(exp_cntry_multi_def_cd_upd_chg) -> target(OUT_CURR_IN)
# source(OUT_DW_LOAD_TS) -> transformation(exp_cntry_multi_def_cd_upd_chg) -> target(OUT_DW_LOAD_TS)
# source(SWB_CNTRY_ID) -> transformation(SQ_CNTRY_MULTI_DEF_CD_T_UPD_DEL) -> target(SWB_CNTRY_ID)
# source(CNTRY_TYPE_CD) -> transformation(SQ_CNTRY_MULTI_DEF_CD_T_UPD_DEL) -> target(CNTRY_TYPE_CD)
# source(DW_EFF_DT) -> transformation(SQ_CNTRY_MULTI_DEF_CD_T_UPD_DEL) -> target(DW_EFF_DT)
# source(IN_DW_AS_OF_DT) -> transformation(SQ_CNTRY_MULTI_DEF_CD_T_UPD_DEL) -> target(IN_DW_AS_OF_DT)
# source(DW_AS_OF_DT) -> transformation(CNTRY_MULTI_DEF_CD_S_UPD_DEL) -> target(IN_DW_AS_OF_DT)
# source(SWB_CNTRY_ID) -> transformation(CNTRY_MULTI_DEF_CD_T_UPD_DEL) -> target(SWB_CNTRY_ID)
# source(CNTRY_TYPE_CD) -> transformation(CNTRY_MULTI_DEF_CD_T_UPD_DEL) -> target(CNTRY_TYPE_CD)
# source(DW_EFF_DT) -> transformation(CNTRY_MULTI_DEF_CD_T_UPD_DEL) -> target(DW_EFF_DT)
# source(SWB_CNTRY_ID) -> transformation(SQ_CNTRY_MULTI_DEF_CD_T_UPD_CHG) -> target(SWB_CNTRY_ID)
# source(CNTRY_TYPE_CD) -> transformation(SQ_CNTRY_MULTI_DEF_CD_T_UPD_CHG) -> target(CNTRY_TYPE_CD)
# source(DW_EFF_DT) -> transformation(SQ_CNTRY_MULTI_DEF_CD_T_UPD_CHG) -> target(DW_EFF_DT)
# source(IN_DW_AS_OF_DT) -> transformation(SQ_CNTRY_MULTI_DEF_CD_T_UPD_CHG) -> target(IN_DW_AS_OF_DT)
# source(SWB_CNTRY_ID) -> transformation(CNTRY_MULTI_DEF_CD_T_UPD_CHG) -> target(SWB_CNTRY_ID)
# source(CNTRY_TYPE_CD) -> transformation(CNTRY_MULTI_DEF_CD_T_UPD_CHG) -> target(CNTRY_TYPE_CD)
# source(DW_EFF_DT) -> transformation(CNTRY_MULTI_DEF_CD_T_UPD_CHG) -> target(DW_EFF_DT)
# source(DW_AS_OF_DT) -> transformation(CNTRY_MULTI_DEF_CD_S_UPD_CHG) -> target(IN_DW_AS_OF_DT)
# source(CNTRY_SCHM_VALD_IN) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(CNTRY_SCHM_VALD_IN)
# source(AUDIT_UPDT_USER_ID) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(AUDIT_UPDT_USER_ID)
# source(AUDIT_UPDT_TS) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(AUDIT_UPDT_TS)
# source(SWB_CNTRY_ID) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(SWB_CNTRY_ID)
# source(SWB_CNTRY_ID) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(SWB_CNTRY_ID)
# source(CNTRY_SCHEME_CD) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(CNTRY_SCHEME_CD)
# source(DW_AS_OF_DT) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(DW_AS_OF_DT)
# source(CNTRY_CD) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(CNTRY_CD)
# source(CNTRY_NM) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(CNTRY_NM)
# source(CNTRY_SCHM_VALD_IN) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(CNTRY_SCHM_VALD_IN)
# source(AUDIT_UPDT_USER_ID) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(AUDIT_UPDT_USER_ID)
# source(AUDIT_UPDT_TS) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(AUDIT_UPDT_TS)
# source(CNTRY_SCHEME_CD) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(CNTRY_SCHEME_CD)
# source(DW_AS_OF_DT) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(DW_AS_OF_DT)
# source(CNTRY_CD) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(CNTRY_CD)
# source(CNTRY_NM) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_NEW) -> target(CNTRY_NM)
# source(SWB_CNTRY_ID) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(SWB_CNTRY_ID)
# source(CNTRY_SCHEME_CD) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(CNTRY_SCHEME_CD)
# source(DW_AS_OF_DT) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(DW_AS_OF_DT)
# source(CNTRY_NM) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(CNTRY_NM)
# source(CNTRY_SCHM_VALD_IN) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(CNTRY_SCHM_VALD_IN)
# source(AUDIT_UPDT_USER_ID) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(AUDIT_UPDT_USER_ID)
# source(AUDIT_UPDT_TS) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(AUDIT_UPDT_TS)
# source(CNTRY_CD) -> transformation(SQ_CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(CNTRY_CD)
# source(SWB_CNTRY_ID) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(SWB_CNTRY_ID)
# source(CNTRY_SCHEME_CD) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(CNTRY_SCHEME_CD)
# source(DW_AS_OF_DT) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(DW_AS_OF_DT)
# source(CNTRY_CD) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(CNTRY_CD)
# source(CNTRY_NM) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(CNTRY_NM)
# source(CNTRY_SCHM_VALD_IN) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(CNTRY_SCHM_VALD_IN)
# source(AUDIT_UPDT_USER_ID) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(AUDIT_UPDT_USER_ID)
# source(AUDIT_UPDT_TS) -> transformation(CNTRY_MULTI_DEF_CD_S_INS_DEL) -> target(AUDIT_UPDT_TS)
# source(SWB_CNTRY_ID) -> transformation(exp_cntry_multi_def_cd_upd_del) -> target(SWB_CNTRY_ID)
# source(CNTRY_TYPE_CD) -> transformation(exp_cntry_multi_def_cd_upd_del) -> target(CNTRY_TYPE_CD)
# source(DW_EFF_DT) -> transformation(exp_cntry_multi_def_cd_upd_del) -> target(DW_EFF_DT)
# source(OUT_DW_EXPR_DT) -> transformation(exp_cntry_multi_def_cd_upd_del) -> target(OUT_DW_EXPR_DT)
# source(OUT_CURR_IN) -> transformation(exp_cntry_multi_def_cd_upd_del) -> target(OUT_CURR_IN)
# source(OUT_DW_LOAD_TS) -> transformation(exp_cntry_multi_def_cd_upd_del) -> target(OUT_DW_LOAD_TS)
# {'source => ': 'None',
#  'trans => ': 'SESSSTARTTIME',
#  'target => ': 'OUT_DW_LOAD_TS'}
